# %% [markdown]
# # Bank Marketing Analiza Dataseta

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

import seaborn as sns
sns.set()

from pylab import rcParams
rcParams['figure.figsize'] = 5, 4

# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option('display.max_columns', 60)
pd.set_option('display.max_rows', 20)

# %% [markdown]
# ## Učitavanje dataseta

# %%
df = pd.read_csv('data/bank-additional.csv', delimiter=';')
df.head()
# Out:
#    age          job  marital          education default  housing     loan  \
# 0   30  blue-collar  married           basic.9y      no      yes       no
# 1   39     services   single        high.school      no       no       no
# 2   25     services  married        high.school      no      yes       no
# 3   38     services  married           basic.9y      no  unknown  unknown
# 4   47       admin.  married  university.degree      no      yes       no
#
#      contact month day_of_week  duration  campaign  pdays  previous  \
# 0   cellular   may         fri     487.0       2.0    999       0.0
# 1  telephone   may         fri     346.0       4.0    999       0.0
# 2  telephone   jun         wed     227.0       1.0    999       0.0
# 3  telephone   jun         fri      17.0       3.0    999       0.0
# 4   cellular   nov         mon      58.0       1.0    999       0.0
#
#       poutcome  emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 0  nonexistent          -1.8          92.893          -46.2      1.313
# 1  nonexistent           1.1          93.994          -36.4      4.855
# 2  nonexistent           1.4          94.465          -41.8      4.962
# 3  nonexistent           1.4          94.465          -41.8      4.959
# 4  nonexistent          -0.1          93.200          -42.0      4.191
#
#   nr.employed   y
# 0      5099.1  no
# 1        5191  no
# 2      5228.1  no
# 3      5228.1  no
# 4      5195.8  no

# %% [markdown]
# ## Profil podataka: Raspodele, deskriptivne statistike, najčešće vrednosti, nedostajuće vrednosti

# %%
import pandas_profiling
df_profile = pandas_profiling.ProfileReport(df)
df_profile.to_file(outputfile='index.html')
print('Profile is saved in index.html')
# Out:
# Profile is saved in index.html

# %%
df.describe()
# Out:
#                age     duration     campaign        pdays     previous  \
# count  4119.000000  4116.000000  4114.000000  4119.000000  4117.000000
# mean     40.113620   256.869048     2.534273   960.422190     0.190430
# std      10.313362   254.763913     2.566673   191.922786     0.541904
# min      18.000000     0.000000     1.000000     0.000000     0.000000
# 25%      32.000000   103.000000     1.000000   999.000000     0.000000
# 50%      38.000000   181.000000     2.000000   999.000000     0.000000
# 75%      47.000000   317.250000     3.000000   999.000000     0.000000
# max      88.000000  3643.000000    35.000000   999.000000     6.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx    euribor3m
# count   4116.000000     4117.000000    4117.000000  4117.000000
# mean       0.084694       93.579540     -40.486358     4.858993
# std        1.563361        0.579442       4.639840    79.432456
# min       -3.400000       92.201000     -50.800000     0.635000
# 25%       -1.800000       93.075000     -42.700000     1.334000
# 50%        1.100000       93.749000     -41.800000     4.857000
# 75%        1.400000       93.994000     -36.400000     4.961000
# max        1.400000       94.767000       1.266000  5099.100000

# %%
df.describe(include=['object'])
# Out:
#            job  marital          education default housing  loan   contact  \
# count     4119     4119               4119    4119    4119  4119      4119
# unique      12        4                  8       3       3     3         2
# top     admin.  married  university.degree      no     yes    no  cellular
# freq      1012     2509               1264    3315    2175  3349      2652
#
#        month day_of_week     poutcome nr.employed     y
# count   4119        4119         4119        4118  4118
# unique    10           5            3          12     2
# top      may         thu  nonexistent      5228.1    no
# freq    1378         860         3523        1625  3667

# %%
df['nr.employed'].value_counts()
# Out:
# 5228.1    1625
# 5099.1     822
# 5191       758
# 5195.8     392
# 5076.2     164
# 5017.5     104
# 4991.6      87
# 4963.6      83
# 5008.7      60
# 5023.5      21
# 5176.3       1
# no           1
# Name: nr.employed, dtype: int64

# %%
df[df['nr.employed'] == 'no']
# Out:
#      age          job  marital education default housing loan   contact month  \
# 780   32  blue-collar  married  basic.4y      no      no  yes  cellular   may
#
#     day_of_week  duration  campaign  pdays  previous     poutcome  \
# 780         thu      80.0       4.0    999       0.0  nonexistent
#
#      emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m nr.employed    y
# 780          -1.8          92.893          1.266     5099.1          no  NaN

# %%
df['nr.employed'] = df['nr.employed'].replace({'no' : df['nr.employed'].mode().values[0]})

# %%
df['nr.employed'] = df['nr.employed'].astype('float')

# %%
df.describe()
# Out:
#                age     duration     campaign        pdays     previous  \
# count  4119.000000  4116.000000  4114.000000  4119.000000  4117.000000
# mean     40.113620   256.869048     2.534273   960.422190     0.190430
# std      10.313362   254.763913     2.566673   191.922786     0.541904
# min      18.000000     0.000000     1.000000     0.000000     0.000000
# 25%      32.000000   103.000000     1.000000   999.000000     0.000000
# 50%      38.000000   181.000000     2.000000   999.000000     0.000000
# 75%      47.000000   317.250000     3.000000   999.000000     0.000000
# max      88.000000  3643.000000    35.000000   999.000000     6.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx    euribor3m  nr.employed
# count   4116.000000     4117.000000    4117.000000  4117.000000  4118.000000
# mean       0.084694       93.579540     -40.486358     4.858993  5166.498057
# std        1.563361        0.579442       4.639840    79.432456    73.669363
# min       -3.400000       92.201000     -50.800000     0.635000  4963.600000
# 25%       -1.800000       93.075000     -42.700000     1.334000  5099.100000
# 50%        1.100000       93.749000     -41.800000     4.857000  5191.000000
# 75%        1.400000       93.994000     -36.400000     4.961000  5228.100000
# max        1.400000       94.767000       1.266000  5099.100000  5228.100000

# %% [markdown]
# ## Korelacije

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64'] 
numeric_df = df.select_dtypes(include=numerics)

corr_matrix = numeric_df.corr(method='pearson')

sns.heatmap(corr_matrix)

# %% [markdown]
# ## Vizualizacija podataka

# %%
df['calls'] = df['previous'] + df['campaign']

# %%
sns.pairplot(df[['age', 'duration', 'calls','euribor3m', 'nr.employed']])

# %%
sns.jointplot(x='duration', y='age', data = df, kind = 'kde')

# %%
sns.lmplot('calls', 'age', data=df, hue='y', markers=["o", "x"])

# %%
sns.violinplot(x='y', y='nr.employed', data=df)

# %%
rcParams['figure.figsize'] = 16,8
sns.boxplot(x='job', y='age', data=df)

# %%
sns.catplot(x='y', y='age', col='loan', data=df, kind='box')

# %%
sns.countplot(x='education', hue='y', data=df)

# %%
pd.crosstab(df['y'], df['education'])
# Out:
# education  basic.4y  basic.6y  basic.9y  high.school  illiterate  \
# y
# no              390       211       531          824           1
# yes              38        17        43           97           0
#
# education  professional.course  university.degree  unknown
# y
# no                         470               1099      141
# yes                         65                165       26

# %% [markdown]
# ## Priprema podataka

# %% [markdown]
# ### Popunjavanje nedostajućih vrednosti

# %%
df.isnull().sum().sum()
# Out:
# 28

# %%
for col in list(df.columns):
    print(col, df[col].isnull().sum())
# Out:
# age 0
# job 0
# marital 0
# education 0
# default 0
# housing 0
# loan 0
# contact 0
# month 0
# day_of_week 0
# duration 0
# campaign 0
# pdays 0
# previous 0
# poutcome 0
# emp.var.rate 0
# cons.price.idx 0
# cons.conf.idx 0
# euribor3m 0
# nr.employed 0
# y 0

# %%
df = df.dropna(subset=['y'])

# %%
df.drop(columns=['calls'], inplace=True)

# %%
econ_cols = ['emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed']
for col in econ_cols:
    df[col] = df[col].fillna(df[col].mode().values[0])

# %%
df[df.previous.isnull()]
# Out:
#      age           job  marital          education  default housing loan  \
# 279   23  entrepreneur  married  university.degree       no     yes   no
# 625   27      services   single        high.school  unknown      no   no
#
#       contact month day_of_week  duration  campaign  pdays  previous  \
# 279  cellular   aug         thu      87.0       1.0    999       NaN
# 625  cellular   jul         tue     509.0       4.0    999       NaN
#
#         poutcome  emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 279  nonexistent           1.4          93.444          -36.1      4.964
# 625  nonexistent           1.4          93.918          -42.7      4.962
#
#      nr.employed    y
# 279       5228.1   no
# 625       5228.1  yes

# %%
sns.countplot(x='previous', data=df)

# %%
df.previous = df.previous.fillna(0.0)

# %%
df[df.campaign.isnull()]
# Out:
#      age          job  marital            education  default  housing  \
# 117   53     services  married          high.school  unknown       no
# 312   30   technician  married    university.degree  unknown      yes
# 375   31   technician   single  professional.course       no  unknown
# 563   47      retired  married             basic.4y  unknown  unknown
# 687   42  blue-collar  married             basic.9y  unknown       no
#
#         loan    contact month day_of_week  duration  campaign  pdays  \
# 117       no  telephone   may         thu     203.0       NaN    999
# 312       no  telephone   may         wed      72.0       NaN    999
# 375  unknown   cellular   aug         mon     202.0       NaN    999
# 563  unknown  telephone   may         wed     441.0       NaN    999
# 687       no  telephone   may         fri     148.0       NaN    999
#
#      previous     poutcome  emp.var.rate  cons.price.idx  cons.conf.idx  \
# 117       0.0  nonexistent           1.1          93.994          -36.4
# 312       0.0  nonexistent           1.1          93.994          -36.4
# 375       0.0  nonexistent           1.4          93.444          -36.1
# 563       0.0  nonexistent           1.1          93.994          -36.4
# 687       0.0  nonexistent           1.1          93.994          -36.4
#
#      euribor3m  nr.employed   y
# 117      4.860       5191.0  no
# 312      4.858       5191.0  no
# 375      4.963       5228.1  no
# 563      4.856       5191.0  no
# 687      4.859       5191.0  no

# %%
df.campaign.describe()
# Out:
# count    4113.000000
# mean        2.533917
# std         2.566883
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         3.000000
# max        35.000000
# Name: campaign, dtype: float64

# %%
df.campaign = df.campaign.fillna(df.campaign.mode().values[0])

# %%
df[df.duration.isnull()]
# Out:
#      age          job   marital          education  default housing loan  \
# 9     35  blue-collar   married           basic.9y  unknown      no   no
# 149   40       admin.  divorced  university.degree       no     yes   no
# 344   51      unknown   married            unknown  unknown     yes   no
#
#        contact month day_of_week  duration  campaign  pdays  previous  \
# 9    telephone   may         thu       NaN       1.0    999       0.0
# 149   cellular   aug         mon       NaN       1.0    999       0.0
# 344   cellular   aug         fri       NaN       5.0    999       0.0
#
#         poutcome  emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 9    nonexistent           1.1          93.994          -36.4      4.855
# 149  nonexistent           1.4          93.444          -36.1      4.965
# 344  nonexistent           1.4          93.444          -36.1      4.963
#
#      nr.employed   y
# 9         5191.0  no
# 149       5228.1  no
# 344       5228.1  no

# %%
df.duration.describe()
# Out:
# count    4115.000000
# mean      256.912029
# std       254.779948
# min         0.000000
# 25%       103.000000
# 50%       181.000000
# 75%       317.500000
# max      3643.000000
# Name: duration, dtype: float64

# %%
df.duration = df.duration.fillna(df.duration.mode().values[0])

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ### Rad sa kategoričkim atributima

# %%
df.describe(include=['object'])
# Out:
#            job  marital          education default housing  loan   contact  \
# count     4118     4118               4118    4118    4118  4118      4118
# unique      12        4                  8       3       3     3         2
# top     admin.  married  university.degree      no     yes    no  cellular
# freq      1012     2508               1264    3314    2175  3349      2651
#
#        month day_of_week     poutcome     y
# count   4118        4118         4118  4118
# unique    10           5            3     2
# top      may         thu  nonexistent    no
# freq    1377         859         3522  3667

# %%
df.default.value_counts()
# Out:
# no         3314
# unknown     803
# yes           1
# Name: default, dtype: int64

# %%
pd.crosstab(df['y'], df['default'])
# Out:
# default    no  unknown  yes
# y
# no       2912      754    1
# yes       402       49    0

# %%
df.drop(columns=['default'], inplace=True)

# %%
df.education.unique()
# Out:
# array(['basic.9y', 'high.school', 'university.degree',
#        'professional.course', 'basic.6y', 'basic.4y', 'unknown',
#        'illiterate'], dtype=object)

# %%
education_mapping_dict = {
    'illiterate': 0,
    'unknown': 1,
    'basic.4y': 1,
    'basic.6y': 2,
    'basic.9y': 3,
    'high.school' : 4,
    'professional.course': 5,
    'university.degree': 6
}
df.education.replace(education_mapping_dict, inplace=True)

# %%
df.education.value_counts()
# Out:
# 6    1264
# 4     921
# 1     595
# 3     574
# 5     535
# 2     228
# 0       1
# Name: education, dtype: int64

# %%
df.month.unique()
# Out:
# array(['may', 'jun', 'nov', 'sep', 'jul', 'aug', 'mar', 'oct', 'apr',
#        'dec'], dtype=object)

# %%
month_mapping_dict = {
    'mar': 3, 
    'apr': 4,
    'may': 5, 
    'jun': 6, 
    'jul': 7, 
    'aug': 8, 
    'sep': 9, 
    'oct': 10,
    'nov': 11,
    'dec': 12
}
df.month.replace(month_mapping_dict, inplace=True)

# %%
df.day_of_week.unique()
# Out:
# array(['fri', 'wed', 'mon', 'thu', 'tue'], dtype=object)

# %%
day_of_week_dict = {
    'mon': 1,
    'tue': 2,
    'wed': 3,
    'thu': 4,
    'fri': 5
}
df.day_of_week.replace(day_of_week_dict, inplace=True)

# %%
df.describe(include=['object'])
# Out:
#            job  marital housing  loan   contact     poutcome     y
# count     4118     4118    4118  4118      4118         4118  4118
# unique      12        4       3     3         2            3     2
# top     admin.  married     yes    no  cellular  nonexistent    no
# freq      1012     2508    2175  3349      2651         3522  3667

# %%
df.marital.value_counts()
# Out:
# married     2508
# single      1153
# divorced     446
# unknown       11
# Name: marital, dtype: int64

# %%
df.housing.value_counts()
# Out:
# yes        2175
# no         1838
# unknown     105
# Name: housing, dtype: int64

# %%
df.query('housing == \'unknown\'').describe(include=['object'])
# Out:
#                 job  marital  housing     loan   contact     poutcome    y
# count           105      105      105      105       105          105  105
# unique           10        3        1        1         2            3    2
# top     blue-collar  married  unknown  unknown  cellular  nonexistent   no
# freq             28       68      105      105        62           86   96

# %%
df.query('housing == \'unknown\' and education < 4 and age < 30').shape
# Out:
# (4, 20)
